# %% [markdown]
# # Tworzenie wizualizacji danych za pomocą pakietów `matplotlib` i `seaborn`

# %%
import seaborn as sns
import pandas as pd
# %matplotlib inline
pd.set_option('max_columns', 50)

# %%
data = pd.read_csv('semantic_prosody_utterly_totally_Daniel.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-44e3f08f9434> in <module>
# ----> 1 data = pd.read_csv('semantic_prosody_utterly_totally_Daniel.csv')
#
# ~/.local/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
data.head()
# Out:
#    Unnamed: 0                 V1                    V2         V3  V4  V5  \
# 0           0  R_2mWfZJ9VaGH3fj7  Default Response Set  Anonymous NaN NaN
# 1           1  R_50zAgUhb6Wufh7n  Default Response Set  Anonymous NaN NaN
# 2           2  R_1RkGNnicRpNWvhX  Default Response Set  Anonymous NaN NaN
# 3           3  R_dosxrkXUVIAqwDj  Default Response Set  Anonymous NaN NaN
# 4           4  R_2nkqcrfLSiFlcKV  Default Response Set  Anonymous NaN NaN
#
#         V6  V7                   V8                   V9  V10      MID  \
# 0  removed   0  2014-08-04 08:55:55  2014-08-04 08:59:25  1.0  removed
# 1  removed   0  2014-08-04 08:56:42  2014-08-04 08:59:44  1.0  removed
# 2  removed   0  2014-08-04 08:56:59  2014-08-04 09:03:47  1.0  removed
# 3  removed   0  2014-08-04 08:57:23  2014-08-04 09:02:27  1.0  removed
# 4  removed   0  2014-08-04 08:57:34  2014-08-04 09:02:07  1.0  removed
#
#    u_warm  u_gn  u_sincere  u_friendly  u_wi  u_trustworthy  u_competent  \
# ...

# %% [markdown]
# # Podstawowe typy wykresów

# %% [markdown]
# ## Histogramy

# %% [markdown]
# ## Wykresy punktowe (*scatterplot*)

# %% [markdown]
# ## Wykresy pudełkowe

# %% [markdown]
# # Wykresy łączone w pakiecie `seaborn`

# %% [markdown]
# # Przygotowywanie wykresów do publikacji
